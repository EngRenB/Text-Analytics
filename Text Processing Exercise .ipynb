# %%
#Remove duplicates
#Remove punctuations and special characters
#Remove digits
#Convert to lowercase
#Remove stopwords
#Perform stemming & lemmatization

# %%
# imported packages

import pandas as pd
import string
import re

#NLTK packages 
import nltk
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /Users/Ren/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("AmazonReviews.csv")
df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
# selecting the Column Text to clean separetly into a new var
TextCleaning = df['Text']
TextCleaning
# Out:
# 0         I have bought several of the Vitality canned d...
# 1         Product arrived labeled as Jumbo Salted Peanut...
# 2         This is a confection that has been around a fe...
# 3         If you are looking for the secret ingredient i...
# 4         Great taffy at a great price.  There was a wid...
#                                 ...
# 568449    Great for sesame chicken..this is a good if no...
# 568450    I'm disappointed with the flavor. The chocolat...
# 568451    These stars are small, so you can give 10-15 o...
# 568452    These are the BEST treats for training and rew...
# 568453    I am very satisfied ,product is as advertised,...
# Name: Text, Length: 568454, dtype: object

# %%
# check for the number of duplicates
DuplicatesRemoved = TextCleaning.duplicated()
print(DuplicatesRemoved.sum())
# Out:
# 174875

# %%
#remove duplicated values
DuplicatesRemoved = TextCleaning.drop_duplicates(keep = 'first')
DuplicatesRemoved
# Out:
# 0         I have bought several of the Vitality canned d...
# 1         Product arrived labeled as Jumbo Salted Peanut...
# 2         This is a confection that has been around a fe...
# 3         If you are looking for the secret ingredient i...
# 4         Great taffy at a great price.  There was a wid...
#                                 ...
# 568449    Great for sesame chicken..this is a good if no...
# 568450    I'm disappointed with the flavor. The chocolat...
# 568451    These stars are small, so you can give 10-15 o...
# 568452    These are the BEST treats for training and rew...
# 568453    I am very satisfied ,product is as advertised,...
# Name: Text, Length: 393579, dtype: object

# %%
#Remove HTMl tags

def get_cleaned_textdata(text):
    #Remove HTMl tags
    cleanedText = re.sub(r'<.*?>','', text)
    #replace punctuation and Special Characters
    cleanedText = ''.join([i if i not in string.punctuation else '' for i in cleanedText])
    #remove digits
    cleanedText = re.sub("[\d+]",'',text)
    #replace multipable spcapes with single space
    cleanedText = re.sub(r'\s+','', text)
    #convert to lower case letters
    cleanedText = cleanedText.lower()
    return cleanedText

# %%
fullCleaned = DuplicatesRemoved.apply(get_cleaned_textdata)

# %%
#tokinazition

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def remove_stopwords(text):
    wordClear = []
    for word in text:
        if word not in stopwords:
            wordClear.append(word)
    return wordClear

# %%
StopwordsRemoved = fullCleaned.apply(get_cleaned_textdata)
StopwordsRemoved
# Out:
# 0         [I,  , h, v, e,  , b, u, g, h,  , e, v, e, r, ...
# 1         [P, r, u, c,  , r, r, v, e,  , l, b, e, l, e, ...
# 2         [T, h,  ,  ,  , c, n, f, e, c, n,  , h,  , h, ...
# 3         [I, f,  , u,  , r, e,  , l, k, n, g,  , f, r, ...
# 4         [G, r, e,  , f, f,  ,  ,  , g, r, e,  , p, r, ...
#                                 ...
# 568449    [G, r, e,  , f, r,  , e, e,  , c, h, c, k, e, ...
# 568450    [I,  ,  , p, p, n, e,  , w, h,  , h, e,  , f, ...
# 568451    [T, h, e, e,  , r,  , r, e,  , l, l,  ,  ,  , ...
# 568452    [T, h, e, e,  , r, e,  , h, e,  , B, E, S, T, ...
# 568453    [I,  ,  , v, e, r,  , f, e,  ,  , p, r, u, c, ...
# Name: Text, Length: 393579, dtype: object
